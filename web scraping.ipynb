# %%
import pandas as pd
import requests
import numpy as np
from bs4 import BeautifulSoup

# %%
requests.get('https://www.ambitionbox.com/list-of-companies?page=1').text
# Out:
# '<HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</HEAD><BODY>\n<H1>Access Denied</H1>\n \nYou don\'t have permission to access "http&#58;&#47;&#47;www&#46;ambitionbox&#46;com&#47;list&#45;of&#45;companies&#63;" on this server.<P>\nReference&#32;&#35;18&#46;8eb61160&#46;1707462655&#46;7500ffc\n</BODY>\n</HTML>\n'

# %% [markdown]
# we getting this error because the Some websites may block access from specific user agents (browser or bot identification). Modifying the User-Agent header in your request might help in some cases.

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
webpage = requests.get('https://www.ambitionbox.com/list-of-companies?page=1', headers=headers).text

# %% [markdown]
# When web scraping, including appropriate headers in your HTTP requests can help mimic the behavior of a legitimate browser and reduce the chances of being blocked or encountering access issues

# %% [markdown]
# # creating a variable to extract necessary information

# %%
soup = BeautifulSoup(webpage, 'lxml')

# %% [markdown]
# The line soup = BeautifulSoup(webpage, 'lxml') is creating a BeautifulSoup object named soup by parsing an HTML or XML document represented by the variable webpage. The second argument, 'lxml', specifies the parser to be used by BeautifulSoup.
#
#
# 'lxml': This is the parser to be used by BeautifulSoup. BeautifulSoup supports different parsers, and 'lxml' is one of them. It refers to the lxml library, which is a high-performance library for processing XML and HTML. Using 'lxml' as the parser often results in faster parsing compared to other parsers.
#
# The purpose of using BeautifulSoup is to provide a convenient way to navigate and search the HTML or XML tree. Once you have a BeautifulSoup object (soup), you can use its methods and attributes to extract information from the parsed document easily.

# %%
print(soup.prettify())

# %% [markdown]
# The line print(soup.prettify()) is used to output the HTML content of a BeautifulSoup object in a formatted and visually structured way.
#
# prettify(): This is a method provided by BeautifulSoup. When called on a BeautifulSoup object, it returns a string containing a "pretty-printed" version of the HTML or XML tree. Pretty-printing means that the structure of the document is indented and formatted in a way that makes it more human-readable.
#
# So, when you execute print(soup.prettify()), it will print a nicely formatted version of the HTML content represented by the soup object. This can be especially useful for debugging, understanding the structure of the document, or simply for a more readable representation of the HTML when working in a console or script.

# %%
soup.find_all('h1')
# Out:
# [<h1 class="companyListing__title">
#  							List of companies in India
#  						</h1>]

# %% [markdown]
# give you all the h1 tags in this situation there is only one header

# %%
soup.find_all('h1')[0].text
# Out:
# '\n\t\t\t\t\t\t\tList of companies in India\n\t\t\t\t\t\t'

# %% [markdown]
# if there were multiple line we can use indexing to extract information and .text to convert it into text format

# %% [markdown]
# # fetching all the names

# %%
for i in soup.find_all('h2'):
    print(i.text.strip())
# Out:
# TCS
# Accenture
# Cognizant
# Wipro
# Capgemini
# HDFC Bank
# ICICI Bank
# Infosys
# HCLTech
# Tech Mahindra
# Genpact
# Axis Bank
# Teleperformance
# Concentrix Corporation
# Jio
# Amazon
# IBM
# Larsen & Toubro Limited
# Reliance Retail
# HDB Financial Services
# Companies by  Industry
# Companies by  Locations
# Companies by  Type
# Companies by  Badges

# %% [markdown]
# using a loop to extract all the h2 tags and print it and using strip() function to remove the spaces

# %% [markdown]
# # Fetching rating

# %%
ratings = soup.find_all('span', class_='companyCardWrapper__companyRatingValue')

for rating in ratings:
    print(rating.text.strip())
# Out:
# 3.8
# 4.0
# 3.9
# 3.8
# 3.9
# 3.9
# 4.0
# 3.8
# 3.7
# 3.7
# 3.9
# 3.9
# 3.6
# 3.9
# 4.0
# 4.1
# 4.1
# 4.0
# 3.9
# 4.0

# %% [markdown]
# When we use find_all in 'BeautifulSoup', it returns a 'ResultSet', which is essentially a list-like object containing all the elements that match our specified criteria. Since there could be multiple elements that match, you receive a collection.
#
# When we iterate over the 'ResultSet' using a loop, we can access each individual element in the collection. This is necessary because each element might have different content, and you may want to perform specific operations on each element.

# %%
company = soup.find_all('div', class_ = 'companyCardWrapper')

# %% [markdown]
# Now here what we gonna do is to fetch a single container first and apply it to all

# %%
Name = []
Rating = []
Reviews = []
Industry = []
Employees = []
Domain = []
Years_in_Operation = []
HQ = []
for i in company:
    Name.append(i.find('h2').text.strip())
    Rating.append(i.find('span', class_='companyCardWrapper__companyRatingValue').text.strip())
    Reviews.append(i.find('a', class_='companyCardWrapper__ActionWrapper').text.strip())
    info = i.find('div', class_='companyCardWrapper__interLinkingWrapper').text.strip()
    info_parts = info.split('|')
    if len(info_parts) > 4:
        Industry.append(info_parts[0].strip())
        Employees.append(info_parts[1].strip())
        Domain.append(info_parts[2].strip())
        Years_in_Operation.append(info_parts[3].strip())
        HQ.append(info_parts[4].strip())  
    else:
        Industry.append('N/A')
        Employees.append('N/A')
        Domain.append('N/A')
        Years_in_Operation.append('N/A')
        HQ.append('N/A')

# %% [markdown]
# "We have divided the page into 20 divs, so rather than fetching everything at once, we're going to create a loop to extract the info from the first block and then move to the next block. Also, you should always ask a question while fetching data to determine whether the block will provide you with a single or multiple values (so you will understand where to use 'find' or 'find_all')."

# %%
d = {'Name':Name, 'Rating':Rating, 'Reviews':Reviews, 'Industry':Industry, 'Employee':Employees, 'Domain':Domain, 'Years_in_Operation':Years_in_Operation, 'HQ':HQ}
df = pd.DataFrame(d)

# %%
df
# Out:
#                                          Name Rating     Reviews
# 0                        Panasonic Appliances    4.1  91 Reviews  \
# 1                                Paras Spices    3.7  91 Reviews
# 2               Augustus Healthcare Solutions    3.8  91 Reviews
# 3                        SKS POWER GENERATION    3.2  91 Reviews
# 4                                Veative Labs    3.0  91 Reviews
# 5   Jarvis Technology and Strategy Consulting    3.3  91 Reviews
# 6                         Simplify Healthcare    3.2  91 Reviews
# 7                                  GTPL-KCBPL    3.9  91 Reviews
# 8                                     Meritto    3.2  91 Reviews
# 9                                        G10X    4.6  91 Reviews
# 10                                   Leena AI    3.4  91 Reviews
# 11                                 AlmaBetter    3.5  91 Reviews
# 12                          Conserve Solution    4.0  91 Reviews
# 13                                  Waah Jobs    4.2  91 Reviews
# 14                               AG&P Pratham    3.9  91 Reviews
# 15                            Entra Solutions    3.3  91 Reviews
# 16          Affordable Robotic and Automation    3.7  91 Reviews
# 17                                 Durr India    3.8  91 Reviews
# 18                                     ISKCON    4.2  91 Reviews
# 19                         Muthoot Mercantile    3.2  91 Reviews
#
#                     Industry           Employee   Domain Years_in_Operation
# 0                        NaN                NaN      NaN                NaN  \
# 1                        NaN                NaN      NaN                NaN
# 2                        NaN                NaN      NaN                NaN
# 3                      Power  201-500 Employees   Public       16 years old
# 4                        NaN                NaN      NaN                NaN
# 5                        NaN                NaN      NaN                NaN
# 6                        NaN                NaN      NaN                NaN
# 7                        NaN                NaN      NaN                NaN
# 8                   Internet  201-500 Employees  Startup        7 years old
# 9                        NaN                NaN      NaN                NaN
# 10          Software Product  201-500 Employees  Startup        9 years old
# 11                       NaN                NaN      NaN                NaN
# 12                       NaN                NaN      NaN                NaN
# 13                  Internet     1-10 Employees  Startup        9 years old
# 14                       NaN                NaN      NaN                NaN
# 15                       NaN                NaN      NaN                NaN
# 16  IT Services & Consulting  201-500 Employees   Public       19 years old
# 17                       NaN                NaN      NaN                NaN
# 18                       NaN                NaN      NaN                NaN
# 19                       NaN                NaN      NaN                NaN
#
#                     HQ
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3      Mumbai +13 more
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8      Gurgaon +9 more
# 9                  NaN
# 10     Gurgaon +5 more
# 11                 NaN
# 12                 NaN
# 13  Bangalore +13 more
# 14                 NaN
# 15                 NaN
# 16        Pune +2 more
# 17                 NaN
# 18                 NaN
# 19                 NaN

# %%
import numpy as np

companydf = pd.DataFrame()

for j in range(1, 400):
    url = 'https://www.ambitionbox.com/list-of-companies?page={}'.format(j)
    print(f"Scraping data from page {j}, URL: {url}")
    
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
    webpage = requests.get(url, headers=headers).text
    soup = BeautifulSoup(webpage, 'lxml')
    company = soup.find_all('div', class_='companyCardWrapper')
    
    data = []
    
    for i in company:
        try:
            Name = i.find('h2').text.strip()
            Rating = i.find('span', class_='companyCardWrapper__companyRatingValue').text.strip()
            Reviews = i.find('a', class_='companyCardWrapper__ActionWrapper').text.strip()
            info = i.find('span', class_='companyCardWrapper__interLinking').text.strip()
            info_parts = info.split('|')
            
            Industry = info_parts[0].strip() if len(info_parts) > 0 else np.nan
            Employees = info_parts[1].strip() if len(info_parts) > 1 else np.nan
            Domain = info_parts[2].strip() if len(info_parts) > 2 else np.nan
            Years_in_Operation = info_parts[3].strip() if len(info_parts) > 3 else np.nan
            HQ = info_parts[4].strip() if len(info_parts) > 4 else np.nan
            
            data.append({'Name': Name, 'Rating': Rating, 'Reviews': Reviews,
                         'Industry': Industry, 'Employees': Employees, 'Domain': Domain,
                         'Years_in_Operation': Years_in_Operation, 'HQ': HQ})
        except Exception as e:
            print(f"Error scraping data: {e}")

    df1 = pd.DataFrame(data)
    companydf = pd.concat([companydf, df1], ignore_index=True)

print(f"Total data length: {len(companydf)}")
# Out:
# Scraping data from page 1, URL: https://www.ambitionbox.com/list-of-companies?page=1
# Scraping data from page 2, URL: https://www.ambitionbox.com/list-of-companies?page=2
# Scraping data from page 3, URL: https://www.ambitionbox.com/list-of-companies?page=3
# Scraping data from page 4, URL: https://www.ambitionbox.com/list-of-companies?page=4
# Scraping data from page 5, URL: https://www.ambitionbox.com/list-of-companies?page=5
# Scraping data from page 6, URL: https://www.ambitionbox.com/list-of-companies?page=6
# Scraping data from page 7, URL: https://www.ambitionbox.com/list-of-companies?page=7
# Scraping data from page 8, URL: https://www.ambitionbox.com/list-of-companies?page=8
# Scraping data from page 9, URL: https://www.ambitionbox.com/list-of-companies?page=9
# Scraping data from page 10, URL: https://www.ambitionbox.com/list-of-companies?page=10
# Scraping data from page 11, URL: https://www.ambitionbox.com/list-of-companies?page=11
# Scraping data from page 12, URL: https://www.ambitionbox.com/list-of-companies?page=12
# Scraping data from page 13, URL: https://www.ambitionbox.com/list-of-companies?page=13
# Scraping data from page 14, URL: https://www.ambitionbox.com/list-of-companies?page=14
# Scraping data from page 15, URL: https://www.ambitionbox.com/list-of-companies?page=15
# Scraping data from page 16, URL: https://www.ambitionbox.com/list-of-companies?page=16
# Scraping data from page 17, URL: https://www.ambitionbox.com/list-of-companies?page=17
# Scraping data from page 18, URL: https://www.ambitionbox.com/list-of-companies?page=18
# Scraping data from page 19, URL: https://www.ambitionbox.com/list-of-companies?page=19
# Scraping data from page 20, URL: https://www.ambitionbox.com/list-of-companies?page=20
# Scraping data from page 21, URL: https://www.ambitionbox.com/list-of-companies?page=21
# Scraping data from page 22, URL: https://www.ambitionbox.com/list-of-companies?page=22
# Scraping data from page 23, URL: https://www.ambitionbox.com/list-of-companies?page=23
# Scraping data from page 24, URL: https://www.ambitionbox.com/list-of-companies?page=24
# Scraping data from page 25, URL: https://www.ambitionbox.com/list-of-companies?page=25
# Scraping data from page 26, URL: https://www.ambitionbox.com/list-of-companies?page=26
# Scraping data from page 27, URL: https://www.ambitionbox.com/list-of-companies?page=27
# Scraping data from page 28, URL: https://www.ambitionbox.com/list-of-companies?page=28
# Scraping data from page 29, URL: https://www.ambitionbox.com/list-of-companies?page=29
# Scraping data from page 30, URL: https://www.ambitionbox.com/list-of-companies?page=30
# Scraping data from page 31, URL: https://www.ambitionbox.com/list-of-companies?page=31
# Scraping data from page 32, URL: https://www.ambitionbox.com/list-of-companies?page=32
# Scraping data from page 33, URL: https://www.ambitionbox.com/list-of-companies?page=33
# Scraping data from page 34, URL: https://www.ambitionbox.com/list-of-companies?page=34
# Scraping data from page 35, URL: https://www.ambitionbox.com/list-of-companies?page=35
# Scraping data from page 36, URL: https://www.ambitionbox.com/list-of-companies?page=36
# Scraping data from page 37, URL: https://www.ambitionbox.com/list-of-companies?page=37
# Scraping data from page 38, URL: https://www.ambitionbox.com/list-of-companies?page=38
# Scraping data from page 39, URL: https://www.ambitionbox.com/list-of-companies?page=39
# Scraping data from page 40, URL: https://www.ambitionbox.com/list-of-companies?page=40
# Scraping data from page 41, URL: https://www.ambitionbox.com/list-of-companies?page=41
# Scraping data from page 42, URL: https://www.ambitionbox.com/list-of-companies?page=42
# Scraping data from page 43, URL: https://www.ambitionbox.com/list-of-companies?page=43
# Scraping data from page 44, URL: https://www.ambitionbox.com/list-of-companies?page=44
# Scraping data from page 45, URL: https://www.ambitionbox.com/list-of-companies?page=45
# Scraping data from page 46, URL: https://www.ambitionbox.com/list-of-companies?page=46
# Scraping data from page 47, URL: https://www.ambitionbox.com/list-of-companies?page=47
# Scraping data from page 48, URL: https://www.ambitionbox.com/list-of-companies?page=48
# Scraping data from page 49, URL: https://www.ambitionbox.com/list-of-companies?page=49
# Scraping data from page 50, URL: https://www.ambitionbox.com/list-of-companies?page=50
# Scraping data from page 51, URL: https://www.ambitionbox.com/list-of-companies?page=51
# Scraping data from page 52, URL: https://www.ambitionbox.com/list-of-companies?page=52
# Scraping data from page 53, URL: https://www.ambitionbox.com/list-of-companies?page=53
# Scraping data from page 54, URL: https://www.ambitionbox.com/list-of-companies?page=54
# Scraping data from page 55, URL: https://www.ambitionbox.com/list-of-companies?page=55
# Scraping data from page 56, URL: https://www.ambitionbox.com/list-of-companies?page=56
# Scraping data from page 57, URL: https://www.ambitionbox.com/list-of-companies?page=57
# Scraping data from page 58, URL: https://www.ambitionbox.com/list-of-companies?page=58
# Scraping data from page 59, URL: https://www.ambitionbox.com/list-of-companies?page=59
# Scraping data from page 60, URL: https://www.ambitionbox.com/list-of-companies?page=60
# Scraping data from page 61, URL: https://www.ambitionbox.com/list-of-companies?page=61
# Scraping data from page 62, URL: https://www.ambitionbox.com/list-of-companies?page=62
# Scraping data from page 63, URL: https://www.ambitionbox.com/list-of-companies?page=63
# Scraping data from page 64, URL: https://www.ambitionbox.com/list-of-companies?page=64
# Scraping data from page 65, URL: https://www.ambitionbox.com/list-of-companies?page=65
# Scraping data from page 66, URL: https://www.ambitionbox.com/list-of-companies?page=66
# Scraping data from page 67, URL: https://www.ambitionbox.com/list-of-companies?page=67
# Scraping data from page 68, URL: https://www.ambitionbox.com/list-of-companies?page=68
# Scraping data from page 69, URL: https://www.ambitionbox.com/list-of-companies?page=69
# Scraping data from page 70, URL: https://www.ambitionbox.com/list-of-companies?page=70
# Scraping data from page 71, URL: https://www.ambitionbox.com/list-of-companies?page=71
# Scraping data from page 72, URL: https://www.ambitionbox.com/list-of-companies?page=72
# Scraping data from page 73, URL: https://www.ambitionbox.com/list-of-companies?page=73
# Scraping data from page 74, URL: https://www.ambitionbox.com/list-of-companies?page=74
# Scraping data from page 75, URL: https://www.ambitionbox.com/list-of-companies?page=75
# Scraping data from page 76, URL: https://www.ambitionbox.com/list-of-companies?page=76
# Scraping data from page 77, URL: https://www.ambitionbox.com/list-of-companies?page=77
# Scraping data from page 78, URL: https://www.ambitionbox.com/list-of-companies?page=78
# Scraping data from page 79, URL: https://www.ambitionbox.com/list-of-companies?page=79
# Scraping data from page 80, URL: https://www.ambitionbox.com/list-of-companies?page=80
# Scraping data from page 81, URL: https://www.ambitionbox.com/list-of-companies?page=81
# Scraping data from page 82, URL: https://www.ambitionbox.com/list-of-companies?page=82
# Scraping data from page 83, URL: https://www.ambitionbox.com/list-of-companies?page=83
# Scraping data from page 84, URL: https://www.ambitionbox.com/list-of-companies?page=84
# Scraping data from page 85, URL: https://www.ambitionbox.com/list-of-companies?page=85
# Scraping data from page 86, URL: https://www.ambitionbox.com/list-of-companies?page=86
# Scraping data from page 87, URL: https://www.ambitionbox.com/list-of-companies?page=87
# Scraping data from page 88, URL: https://www.ambitionbox.com/list-of-companies?page=88
# Scraping data from page 89, URL: https://www.ambitionbox.com/list-of-companies?page=89
# Scraping data from page 90, URL: https://www.ambitionbox.com/list-of-companies?page=90
# Scraping data from page 91, URL: https://www.ambitionbox.com/list-of-companies?page=91
# Scraping data from page 92, URL: https://www.ambitionbox.com/list-of-companies?page=92
# Scraping data from page 93, URL: https://www.ambitionbox.com/list-of-companies?page=93
# Scraping data from page 94, URL: https://www.ambitionbox.com/list-of-companies?page=94
# Scraping data from page 95, URL: https://www.ambitionbox.com/list-of-companies?page=95
# Scraping data from page 96, URL: https://www.ambitionbox.com/list-of-companies?page=96
# Scraping data from page 97, URL: https://www.ambitionbox.com/list-of-companies?page=97
# Scraping data from page 98, URL: https://www.ambitionbox.com/list-of-companies?page=98
# Scraping data from page 99, URL: https://www.ambitionbox.com/list-of-companies?page=99
# Scraping data from page 100, URL: https://www.ambitionbox.com/list-of-companies?page=100
# Scraping data from page 101, URL: https://www.ambitionbox.com/list-of-companies?page=101
# Scraping data from page 102, URL: https://www.ambitionbox.com/list-of-companies?page=102
# Scraping data from page 103, URL: https://www.ambitionbox.com/list-of-companies?page=103
# Scraping data from page 104, URL: https://www.ambitionbox.com/list-of-companies?page=104
# Scraping data from page 105, URL: https://www.ambitionbox.com/list-of-companies?page=105
# Scraping data from page 106, URL: https://www.ambitionbox.com/list-of-companies?page=106
# Scraping data from page 107, URL: https://www.ambitionbox.com/list-of-companies?page=107
# Scraping data from page 108, URL: https://www.ambitionbox.com/list-of-companies?page=108
# Scraping data from page 109, URL: https://www.ambitionbox.com/list-of-companies?page=109
# Scraping data from page 110, URL: https://www.ambitionbox.com/list-of-companies?page=110
# Scraping data from page 111, URL: https://www.ambitionbox.com/list-of-companies?page=111
# Scraping data from page 112, URL: https://www.ambitionbox.com/list-of-companies?page=112
# Scraping data from page 113, URL: https://www.ambitionbox.com/list-of-companies?page=113
# Scraping data from page 114, URL: https://www.ambitionbox.com/list-of-companies?page=114
# Scraping data from page 115, URL: https://www.ambitionbox.com/list-of-companies?page=115
# Scraping data from page 116, URL: https://www.ambitionbox.com/list-of-companies?page=116
# Scraping data from page 117, URL: https://www.ambitionbox.com/list-of-companies?page=117
# Scraping data from page 118, URL: https://www.ambitionbox.com/list-of-companies?page=118
# Scraping data from page 119, URL: https://www.ambitionbox.com/list-of-companies?page=119
# Scraping data from page 120, URL: https://www.ambitionbox.com/list-of-companies?page=120
# Scraping data from page 121, URL: https://www.ambitionbox.com/list-of-companies?page=121
# Scraping data from page 122, URL: https://www.ambitionbox.com/list-of-companies?page=122
# Scraping data from page 123, URL: https://www.ambitionbox.com/list-of-companies?page=123
# Scraping data from page 124, URL: https://www.ambitionbox.com/list-of-companies?page=124
# Scraping data from page 125, URL: https://www.ambitionbox.com/list-of-companies?page=125
# Scraping data from page 126, URL: https://www.ambitionbox.com/list-of-companies?page=126
# Scraping data from page 127, URL: https://www.ambitionbox.com/list-of-companies?page=127
# Scraping data from page 128, URL: https://www.ambitionbox.com/list-of-companies?page=128
# Scraping data from page 129, URL: https://www.ambitionbox.com/list-of-companies?page=129
# Scraping data from page 130, URL: https://www.ambitionbox.com/list-of-companies?page=130
# Scraping data from page 131, URL: https://www.ambitionbox.com/list-of-companies?page=131
# Scraping data from page 132, URL: https://www.ambitionbox.com/list-of-companies?page=132
# Scraping data from page 133, URL: https://www.ambitionbox.com/list-of-companies?page=133
# Scraping data from page 134, URL: https://www.ambitionbox.com/list-of-companies?page=134
# Scraping data from page 135, URL: https://www.ambitionbox.com/list-of-companies?page=135
# Scraping data from page 136, URL: https://www.ambitionbox.com/list-of-companies?page=136
# Scraping data from page 137, URL: https://www.ambitionbox.com/list-of-companies?page=137
# Scraping data from page 138, URL: https://www.ambitionbox.com/list-of-companies?page=138
# Scraping data from page 139, URL: https://www.ambitionbox.com/list-of-companies?page=139
# Scraping data from page 140, URL: https://www.ambitionbox.com/list-of-companies?page=140
# Scraping data from page 141, URL: https://www.ambitionbox.com/list-of-companies?page=141
# Scraping data from page 142, URL: https://www.ambitionbox.com/list-of-companies?page=142
# Scraping data from page 143, URL: https://www.ambitionbox.com/list-of-companies?page=143
# Scraping data from page 144, URL: https://www.ambitionbox.com/list-of-companies?page=144
# Scraping data from page 145, URL: https://www.ambitionbox.com/list-of-companies?page=145
# Scraping data from page 146, URL: https://www.ambitionbox.com/list-of-companies?page=146
# Scraping data from page 147, URL: https://www.ambitionbox.com/list-of-companies?page=147
# Scraping data from page 148, URL: https://www.ambitionbox.com/list-of-companies?page=148
# Scraping data from page 149, URL: https://www.ambitionbox.com/list-of-companies?page=149
# Scraping data from page 150, URL: https://www.ambitionbox.com/list-of-companies?page=150
# Scraping data from page 151, URL: https://www.ambitionbox.com/list-of-companies?page=151
# Scraping data from page 152, URL: https://www.ambitionbox.com/list-of-companies?page=152
# Scraping data from page 153, URL: https://www.ambitionbox.com/list-of-companies?page=153
# Scraping data from page 154, URL: https://www.ambitionbox.com/list-of-companies?page=154
# Scraping data from page 155, URL: https://www.ambitionbox.com/list-of-companies?page=155
# Scraping data from page 156, URL: https://www.ambitionbox.com/list-of-companies?page=156
# Scraping data from page 157, URL: https://www.ambitionbox.com/list-of-companies?page=157
# Scraping data from page 158, URL: https://www.ambitionbox.com/list-of-companies?page=158
# Scraping data from page 159, URL: https://www.ambitionbox.com/list-of-companies?page=159
# Scraping data from page 160, URL: https://www.ambitionbox.com/list-of-companies?page=160
# Scraping data from page 161, URL: https://www.ambitionbox.com/list-of-companies?page=161
# Scraping data from page 162, URL: https://www.ambitionbox.com/list-of-companies?page=162
# Scraping data from page 163, URL: https://www.ambitionbox.com/list-of-companies?page=163
# Scraping data from page 164, URL: https://www.ambitionbox.com/list-of-companies?page=164
# Scraping data from page 165, URL: https://www.ambitionbox.com/list-of-companies?page=165
# Scraping data from page 166, URL: https://www.ambitionbox.com/list-of-companies?page=166
# Scraping data from page 167, URL: https://www.ambitionbox.com/list-of-companies?page=167
# Scraping data from page 168, URL: https://www.ambitionbox.com/list-of-companies?page=168
# Scraping data from page 169, URL: https://www.ambitionbox.com/list-of-companies?page=169
# Scraping data from page 170, URL: https://www.ambitionbox.com/list-of-companies?page=170
# Scraping data from page 171, URL: https://www.ambitionbox.com/list-of-companies?page=171
# Scraping data from page 172, URL: https://www.ambitionbox.com/list-of-companies?page=172
# Scraping data from page 173, URL: https://www.ambitionbox.com/list-of-companies?page=173
# Scraping data from page 174, URL: https://www.ambitionbox.com/list-of-companies?page=174
# Scraping data from page 175, URL: https://www.ambitionbox.com/list-of-companies?page=175
# Scraping data from page 176, URL: https://www.ambitionbox.com/list-of-companies?page=176
# Scraping data from page 177, URL: https://www.ambitionbox.com/list-of-companies?page=177
# Scraping data from page 178, URL: https://www.ambitionbox.com/list-of-companies?page=178
# Scraping data from page 179, URL: https://www.ambitionbox.com/list-of-companies?page=179
# Scraping data from page 180, URL: https://www.ambitionbox.com/list-of-companies?page=180
# Scraping data from page 181, URL: https://www.ambitionbox.com/list-of-companies?page=181
# Scraping data from page 182, URL: https://www.ambitionbox.com/list-of-companies?page=182
# Scraping data from page 183, URL: https://www.ambitionbox.com/list-of-companies?page=183
# Scraping data from page 184, URL: https://www.ambitionbox.com/list-of-companies?page=184
# Scraping data from page 185, URL: https://www.ambitionbox.com/list-of-companies?page=185
# Scraping data from page 186, URL: https://www.ambitionbox.com/list-of-companies?page=186
# Scraping data from page 187, URL: https://www.ambitionbox.com/list-of-companies?page=187
# Scraping data from page 188, URL: https://www.ambitionbox.com/list-of-companies?page=188
# Scraping data from page 189, URL: https://www.ambitionbox.com/list-of-companies?page=189
# Scraping data from page 190, URL: https://www.ambitionbox.com/list-of-companies?page=190
# Scraping data from page 191, URL: https://www.ambitionbox.com/list-of-companies?page=191
# Scraping data from page 192, URL: https://www.ambitionbox.com/list-of-companies?page=192
# Scraping data from page 193, URL: https://www.ambitionbox.com/list-of-companies?page=193
# Scraping data from page 194, URL: https://www.ambitionbox.com/list-of-companies?page=194
# Scraping data from page 195, URL: https://www.ambitionbox.com/list-of-companies?page=195
# Scraping data from page 196, URL: https://www.ambitionbox.com/list-of-companies?page=196
# Scraping data from page 197, URL: https://www.ambitionbox.com/list-of-companies?page=197
# Scraping data from page 198, URL: https://www.ambitionbox.com/list-of-companies?page=198
# Scraping data from page 199, URL: https://www.ambitionbox.com/list-of-companies?page=199
# Scraping data from page 200, URL: https://www.ambitionbox.com/list-of-companies?page=200
# Scraping data from page 201, URL: https://www.ambitionbox.com/list-of-companies?page=201
# Scraping data from page 202, URL: https://www.ambitionbox.com/list-of-companies?page=202
# Scraping data from page 203, URL: https://www.ambitionbox.com/list-of-companies?page=203
# Scraping data from page 204, URL: https://www.ambitionbox.com/list-of-companies?page=204
# Scraping data from page 205, URL: https://www.ambitionbox.com/list-of-companies?page=205
# Scraping data from page 206, URL: https://www.ambitionbox.com/list-of-companies?page=206
# Scraping data from page 207, URL: https://www.ambitionbox.com/list-of-companies?page=207
# Scraping data from page 208, URL: https://www.ambitionbox.com/list-of-companies?page=208
# Scraping data from page 209, URL: https://www.ambitionbox.com/list-of-companies?page=209
# Scraping data from page 210, URL: https://www.ambitionbox.com/list-of-companies?page=210
# Scraping data from page 211, URL: https://www.ambitionbox.com/list-of-companies?page=211
# Scraping data from page 212, URL: https://www.ambitionbox.com/list-of-companies?page=212
# Scraping data from page 213, URL: https://www.ambitionbox.com/list-of-companies?page=213
# Scraping data from page 214, URL: https://www.ambitionbox.com/list-of-companies?page=214
# Scraping data from page 215, URL: https://www.ambitionbox.com/list-of-companies?page=215
# Scraping data from page 216, URL: https://www.ambitionbox.com/list-of-companies?page=216
# Scraping data from page 217, URL: https://www.ambitionbox.com/list-of-companies?page=217
# Scraping data from page 218, URL: https://www.ambitionbox.com/list-of-companies?page=218
# Scraping data from page 219, URL: https://www.ambitionbox.com/list-of-companies?page=219
# Scraping data from page 220, URL: https://www.ambitionbox.com/list-of-companies?page=220
# Scraping data from page 221, URL: https://www.ambitionbox.com/list-of-companies?page=221
# Scraping data from page 222, URL: https://www.ambitionbox.com/list-of-companies?page=222
# Scraping data from page 223, URL: https://www.ambitionbox.com/list-of-companies?page=223
# Scraping data from page 224, URL: https://www.ambitionbox.com/list-of-companies?page=224
# Scraping data from page 225, URL: https://www.ambitionbox.com/list-of-companies?page=225
# Scraping data from page 226, URL: https://www.ambitionbox.com/list-of-companies?page=226
# Scraping data from page 227, URL: https://www.ambitionbox.com/list-of-companies?page=227
# Scraping data from page 228, URL: https://www.ambitionbox.com/list-of-companies?page=228
# Scraping data from page 229, URL: https://www.ambitionbox.com/list-of-companies?page=229
# Scraping data from page 230, URL: https://www.ambitionbox.com/list-of-companies?page=230
# Scraping data from page 231, URL: https://www.ambitionbox.com/list-of-companies?page=231
# Scraping data from page 232, URL: https://www.ambitionbox.com/list-of-companies?page=232
# Scraping data from page 233, URL: https://www.ambitionbox.com/list-of-companies?page=233
# Scraping data from page 234, URL: https://www.ambitionbox.com/list-of-companies?page=234
# Scraping data from page 235, URL: https://www.ambitionbox.com/list-of-companies?page=235
# Scraping data from page 236, URL: https://www.ambitionbox.com/list-of-companies?page=236
# Scraping data from page 237, URL: https://www.ambitionbox.com/list-of-companies?page=237
# Scraping data from page 238, URL: https://www.ambitionbox.com/list-of-companies?page=238
# Scraping data from page 239, URL: https://www.ambitionbox.com/list-of-companies?page=239
# Scraping data from page 240, URL: https://www.ambitionbox.com/list-of-companies?page=240
# Scraping data from page 241, URL: https://www.ambitionbox.com/list-of-companies?page=241
# Scraping data from page 242, URL: https://www.ambitionbox.com/list-of-companies?page=242
# Scraping data from page 243, URL: https://www.ambitionbox.com/list-of-companies?page=243
# Scraping data from page 244, URL: https://www.ambitionbox.com/list-of-companies?page=244
# Scraping data from page 245, URL: https://www.ambitionbox.com/list-of-companies?page=245
# Scraping data from page 246, URL: https://www.ambitionbox.com/list-of-companies?page=246
# Scraping data from page 247, URL: https://www.ambitionbox.com/list-of-companies?page=247
# Scraping data from page 248, URL: https://www.ambitionbox.com/list-of-companies?page=248
# Scraping data from page 249, URL: https://www.ambitionbox.com/list-of-companies?page=249
# Scraping data from page 250, URL: https://www.ambitionbox.com/list-of-companies?page=250
# Scraping data from page 251, URL: https://www.ambitionbox.com/list-of-companies?page=251
# Scraping data from page 252, URL: https://www.ambitionbox.com/list-of-companies?page=252
# Scraping data from page 253, URL: https://www.ambitionbox.com/list-of-companies?page=253
# Scraping data from page 254, URL: https://www.ambitionbox.com/list-of-companies?page=254
# Scraping data from page 255, URL: https://www.ambitionbox.com/list-of-companies?page=255
# Scraping data from page 256, URL: https://www.ambitionbox.com/list-of-companies?page=256
# Scraping data from page 257, URL: https://www.ambitionbox.com/list-of-companies?page=257
# Scraping data from page 258, URL: https://www.ambitionbox.com/list-of-companies?page=258
# Scraping data from page 259, URL: https://www.ambitionbox.com/list-of-companies?page=259
# Scraping data from page 260, URL: https://www.ambitionbox.com/list-of-companies?page=260
# Scraping data from page 261, URL: https://www.ambitionbox.com/list-of-companies?page=261
# Scraping data from page 262, URL: https://www.ambitionbox.com/list-of-companies?page=262
# Scraping data from page 263, URL: https://www.ambitionbox.com/list-of-companies?page=263
# Scraping data from page 264, URL: https://www.ambitionbox.com/list-of-companies?page=264
# Scraping data from page 265, URL: https://www.ambitionbox.com/list-of-companies?page=265
# Scraping data from page 266, URL: https://www.ambitionbox.com/list-of-companies?page=266
# Scraping data from page 267, URL: https://www.ambitionbox.com/list-of-companies?page=267
# Scraping data from page 268, URL: https://www.ambitionbox.com/list-of-companies?page=268
# Scraping data from page 269, URL: https://www.ambitionbox.com/list-of-companies?page=269
# Scraping data from page 270, URL: https://www.ambitionbox.com/list-of-companies?page=270
# Scraping data from page 271, URL: https://www.ambitionbox.com/list-of-companies?page=271
# Scraping data from page 272, URL: https://www.ambitionbox.com/list-of-companies?page=272
# Scraping data from page 273, URL: https://www.ambitionbox.com/list-of-companies?page=273
# Scraping data from page 274, URL: https://www.ambitionbox.com/list-of-companies?page=274
# Scraping data from page 275, URL: https://www.ambitionbox.com/list-of-companies?page=275
# Scraping data from page 276, URL: https://www.ambitionbox.com/list-of-companies?page=276
# Scraping data from page 277, URL: https://www.ambitionbox.com/list-of-companies?page=277
# Scraping data from page 278, URL: https://www.ambitionbox.com/list-of-companies?page=278
# Scraping data from page 279, URL: https://www.ambitionbox.com/list-of-companies?page=279
# Scraping data from page 280, URL: https://www.ambitionbox.com/list-of-companies?page=280
# Scraping data from page 281, URL: https://www.ambitionbox.com/list-of-companies?page=281
# Scraping data from page 282, URL: https://www.ambitionbox.com/list-of-companies?page=282
# Scraping data from page 283, URL: https://www.ambitionbox.com/list-of-companies?page=283
# Scraping data from page 284, URL: https://www.ambitionbox.com/list-of-companies?page=284
# Scraping data from page 285, URL: https://www.ambitionbox.com/list-of-companies?page=285
# Scraping data from page 286, URL: https://www.ambitionbox.com/list-of-companies?page=286
# Scraping data from page 287, URL: https://www.ambitionbox.com/list-of-companies?page=287
# Scraping data from page 288, URL: https://www.ambitionbox.com/list-of-companies?page=288
# Scraping data from page 289, URL: https://www.ambitionbox.com/list-of-companies?page=289
# Scraping data from page 290, URL: https://www.ambitionbox.com/list-of-companies?page=290
# Scraping data from page 291, URL: https://www.ambitionbox.com/list-of-companies?page=291
# Scraping data from page 292, URL: https://www.ambitionbox.com/list-of-companies?page=292
# Scraping data from page 293, URL: https://www.ambitionbox.com/list-of-companies?page=293
# Scraping data from page 294, URL: https://www.ambitionbox.com/list-of-companies?page=294
# Scraping data from page 295, URL: https://www.ambitionbox.com/list-of-companies?page=295
# Scraping data from page 296, URL: https://www.ambitionbox.com/list-of-companies?page=296
# Scraping data from page 297, URL: https://www.ambitionbox.com/list-of-companies?page=297
# Scraping data from page 298, URL: https://www.ambitionbox.com/list-of-companies?page=298
# Scraping data from page 299, URL: https://www.ambitionbox.com/list-of-companies?page=299
# Scraping data from page 300, URL: https://www.ambitionbox.com/list-of-companies?page=300
# Scraping data from page 301, URL: https://www.ambitionbox.com/list-of-companies?page=301
# Scraping data from page 302, URL: https://www.ambitionbox.com/list-of-companies?page=302
# Scraping data from page 303, URL: https://www.ambitionbox.com/list-of-companies?page=303
# Scraping data from page 304, URL: https://www.ambitionbox.com/list-of-companies?page=304
# Scraping data from page 305, URL: https://www.ambitionbox.com/list-of-companies?page=305
# Scraping data from page 306, URL: https://www.ambitionbox.com/list-of-companies?page=306
# Scraping data from page 307, URL: https://www.ambitionbox.com/list-of-companies?page=307
# Scraping data from page 308, URL: https://www.ambitionbox.com/list-of-companies?page=308
# Scraping data from page 309, URL: https://www.ambitionbox.com/list-of-companies?page=309
# Scraping data from page 310, URL: https://www.ambitionbox.com/list-of-companies?page=310
# Scraping data from page 311, URL: https://www.ambitionbox.com/list-of-companies?page=311
# Scraping data from page 312, URL: https://www.ambitionbox.com/list-of-companies?page=312
# Scraping data from page 313, URL: https://www.ambitionbox.com/list-of-companies?page=313
# Scraping data from page 314, URL: https://www.ambitionbox.com/list-of-companies?page=314
# Scraping data from page 315, URL: https://www.ambitionbox.com/list-of-companies?page=315
# Scraping data from page 316, URL: https://www.ambitionbox.com/list-of-companies?page=316
# Scraping data from page 317, URL: https://www.ambitionbox.com/list-of-companies?page=317
# Scraping data from page 318, URL: https://www.ambitionbox.com/list-of-companies?page=318
# Scraping data from page 319, URL: https://www.ambitionbox.com/list-of-companies?page=319
# Scraping data from page 320, URL: https://www.ambitionbox.com/list-of-companies?page=320
# Scraping data from page 321, URL: https://www.ambitionbox.com/list-of-companies?page=321
# Scraping data from page 322, URL: https://www.ambitionbox.com/list-of-companies?page=322
# Scraping data from page 323, URL: https://www.ambitionbox.com/list-of-companies?page=323
# Scraping data from page 324, URL: https://www.ambitionbox.com/list-of-companies?page=324
# Scraping data from page 325, URL: https://www.ambitionbox.com/list-of-companies?page=325
# Scraping data from page 326, URL: https://www.ambitionbox.com/list-of-companies?page=326
# Scraping data from page 327, URL: https://www.ambitionbox.com/list-of-companies?page=327
# Scraping data from page 328, URL: https://www.ambitionbox.com/list-of-companies?page=328
# Scraping data from page 329, URL: https://www.ambitionbox.com/list-of-companies?page=329
# Scraping data from page 330, URL: https://www.ambitionbox.com/list-of-companies?page=330
# Scraping data from page 331, URL: https://www.ambitionbox.com/list-of-companies?page=331
# Scraping data from page 332, URL: https://www.ambitionbox.com/list-of-companies?page=332
# Scraping data from page 333, URL: https://www.ambitionbox.com/list-of-companies?page=333
# Scraping data from page 334, URL: https://www.ambitionbox.com/list-of-companies?page=334
# Scraping data from page 335, URL: https://www.ambitionbox.com/list-of-companies?page=335
# Scraping data from page 336, URL: https://www.ambitionbox.com/list-of-companies?page=336
# Scraping data from page 337, URL: https://www.ambitionbox.com/list-of-companies?page=337
# Scraping data from page 338, URL: https://www.ambitionbox.com/list-of-companies?page=338
# Scraping data from page 339, URL: https://www.ambitionbox.com/list-of-companies?page=339
# Scraping data from page 340, URL: https://www.ambitionbox.com/list-of-companies?page=340
# Scraping data from page 341, URL: https://www.ambitionbox.com/list-of-companies?page=341
# Scraping data from page 342, URL: https://www.ambitionbox.com/list-of-companies?page=342
# Scraping data from page 343, URL: https://www.ambitionbox.com/list-of-companies?page=343
# Scraping data from page 344, URL: https://www.ambitionbox.com/list-of-companies?page=344
# Scraping data from page 345, URL: https://www.ambitionbox.com/list-of-companies?page=345
# Scraping data from page 346, URL: https://www.ambitionbox.com/list-of-companies?page=346
# Scraping data from page 347, URL: https://www.ambitionbox.com/list-of-companies?page=347
# Scraping data from page 348, URL: https://www.ambitionbox.com/list-of-companies?page=348
# Scraping data from page 349, URL: https://www.ambitionbox.com/list-of-companies?page=349
# Scraping data from page 350, URL: https://www.ambitionbox.com/list-of-companies?page=350
# Scraping data from page 351, URL: https://www.ambitionbox.com/list-of-companies?page=351
# Scraping data from page 352, URL: https://www.ambitionbox.com/list-of-companies?page=352
# Scraping data from page 353, URL: https://www.ambitionbox.com/list-of-companies?page=353
# Scraping data from page 354, URL: https://www.ambitionbox.com/list-of-companies?page=354
# Scraping data from page 355, URL: https://www.ambitionbox.com/list-of-companies?page=355
# Scraping data from page 356, URL: https://www.ambitionbox.com/list-of-companies?page=356
# Scraping data from page 357, URL: https://www.ambitionbox.com/list-of-companies?page=357
# Scraping data from page 358, URL: https://www.ambitionbox.com/list-of-companies?page=358
# Scraping data from page 359, URL: https://www.ambitionbox.com/list-of-companies?page=359
# Scraping data from page 360, URL: https://www.ambitionbox.com/list-of-companies?page=360
# Scraping data from page 361, URL: https://www.ambitionbox.com/list-of-companies?page=361
# Scraping data from page 362, URL: https://www.ambitionbox.com/list-of-companies?page=362
# Scraping data from page 363, URL: https://www.ambitionbox.com/list-of-companies?page=363
# Scraping data from page 364, URL: https://www.ambitionbox.com/list-of-companies?page=364
# Scraping data from page 365, URL: https://www.ambitionbox.com/list-of-companies?page=365
# Scraping data from page 366, URL: https://www.ambitionbox.com/list-of-companies?page=366
# Scraping data from page 367, URL: https://www.ambitionbox.com/list-of-companies?page=367
# Scraping data from page 368, URL: https://www.ambitionbox.com/list-of-companies?page=368
# Scraping data from page 369, URL: https://www.ambitionbox.com/list-of-companies?page=369
# Scraping data from page 370, URL: https://www.ambitionbox.com/list-of-companies?page=370
# Scraping data from page 371, URL: https://www.ambitionbox.com/list-of-companies?page=371
# Scraping data from page 372, URL: https://www.ambitionbox.com/list-of-companies?page=372
# Scraping data from page 373, URL: https://www.ambitionbox.com/list-of-companies?page=373
# Scraping data from page 374, URL: https://www.ambitionbox.com/list-of-companies?page=374
# Scraping data from page 375, URL: https://www.ambitionbox.com/list-of-companies?page=375
# Scraping data from page 376, URL: https://www.ambitionbox.com/list-of-companies?page=376
# Scraping data from page 377, URL: https://www.ambitionbox.com/list-of-companies?page=377
# Scraping data from page 378, URL: https://www.ambitionbox.com/list-of-companies?page=378
# Scraping data from page 379, URL: https://www.ambitionbox.com/list-of-companies?page=379
# Scraping data from page 380, URL: https://www.ambitionbox.com/list-of-companies?page=380
# Scraping data from page 381, URL: https://www.ambitionbox.com/list-of-companies?page=381
# Scraping data from page 382, URL: https://www.ambitionbox.com/list-of-companies?page=382
# Scraping data from page 383, URL: https://www.ambitionbox.com/list-of-companies?page=383
# Scraping data from page 384, URL: https://www.ambitionbox.com/list-of-companies?page=384
# Scraping data from page 385, URL: https://www.ambitionbox.com/list-of-companies?page=385
# Scraping data from page 386, URL: https://www.ambitionbox.com/list-of-companies?page=386
# Scraping data from page 387, URL: https://www.ambitionbox.com/list-of-companies?page=387
# Scraping data from page 388, URL: https://www.ambitionbox.com/list-of-companies?page=388
# Scraping data from page 389, URL: https://www.ambitionbox.com/list-of-companies?page=389
# Scraping data from page 390, URL: https://www.ambitionbox.com/list-of-companies?page=390
# Scraping data from page 391, URL: https://www.ambitionbox.com/list-of-companies?page=391
# Scraping data from page 392, URL: https://www.ambitionbox.com/list-of-companies?page=392
# Scraping data from page 393, URL: https://www.ambitionbox.com/list-of-companies?page=393
# Scraping data from page 394, URL: https://www.ambitionbox.com/list-of-companies?page=394
# Scraping data from page 395, URL: https://www.ambitionbox.com/list-of-companies?page=395
# Scraping data from page 396, URL: https://www.ambitionbox.com/list-of-companies?page=396
# Scraping data from page 397, URL: https://www.ambitionbox.com/list-of-companies?page=397
# Scraping data from page 398, URL: https://www.ambitionbox.com/list-of-companies?page=398
# Scraping data from page 399, URL: https://www.ambitionbox.com/list-of-companies?page=399
# Total data length: 7980

# %% [markdown]
# Import Libraries:
#
# import pandas as pd:: Imports the Pandas library for handling data in tabular form.
# import requests:: Enables making HTTP requests to retrieve web pages.
# from bs4 import BeautifulSoup:: Allows for easy extraction of data from HTML.
# import numpy as np::Imports NumPy for numerical operations.
# Initialize DataFrame:
#
# companydf = pd.DataFrame():: Creates an empty Pandas DataFrame named companydf to store the scraped data.
# Loop through Pages::
#
# for j in range(1, 400):: Iterates through page numbers from 1 to 399. This assumes that there are 399 pages to scrape.
# HTTP Request and Parsing::
#
# url = 'https://www.ambitionbox.com/list-of-companies?page={}'.format(j):: Constructs the URL for the current page.
# webpage = requests.get(url, headers=headers).text:: Sends an HTTP GET request to the URL and retrieves the HTML content.
# soup = BeautifulSoup(webpage, 'lxml'):: Creates a BeautifulSoup object to parse the HTML content.
# Extract Company Information::
#
# company = soup.find_all('div', class_='companyCardWrapper'):: Finds all HTML elements with the specified class that represent company cards on the webpage.
# Loop through each company card and extract relevant information::
# Name = i.find('h2').text.strip():: Company name.
# Rating = i.find('span', class_='companyCardWrapper__companyRatingValue').text.strip():: Company rating.
# Reviews = i.find('a', class_='companyCardWrapper__ActionWrapper').text.strip():: Number of reviews.
# info = i.find('span', class_='companyCardWrapper__interLinking').text.strip():: Additional information about the company.
# Split the additional information into parts using info.split('|').
# Assign each part to variables (Industry, Employees, Domain, Years_in_Operation, HQ).
# If a part is missing, assign np.nan (NumPy's representation of missing values).
# Error Handling::
#
# Encloses the information extraction in a try-except block to handle any exceptions that may occur during scraping.
# If an error occurs, it prints an error message.
# Create DataFrame for Current Page:
#
# df1 = pd.DataFrame(data):: Creates a DataFrame (df1) from the extracted data on the current page.
# Concatenate DataFrames::
#
# companydf = pd.concat([companydf, df1], ignore_index=True):: Concatenates the current page's DataFrame with the overall DataFrame (companydf).
# Print Progress::
#
# print(f"Total data length: {len(companydf)}"):: Prints the total length of the DataFrame after scraping all pages

# %%
companydf.shape
# Out:
# (7980, 8)

# %%
companydf.to_csv('company_data.csv', index=False)
